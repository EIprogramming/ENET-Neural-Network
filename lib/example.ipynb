# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from neural_net import NeuralNet
import mushrooms as shroom
import graphics
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
neural_net = NeuralNet((2, 16, 1), learning_rate=0.005, random_state=42)

# %%
X, y = shroom.generate_mushrooms(lambda i, j: (i-0.4)**2 + (j-0.4)**2 < 0.16, size_shrooms=2000)

# %%
epochs = 200
losses, y_pred = neural_net.batch_train_optimized(X, y, epochs=epochs, batch_size=3)
# Out:
# EPOCH: 0    LOSS: 0.7594463068003519    MOMENTUM: 1.02
# EPOCH: 1    LOSS: 0.7297375286241634    MOMENTUM: 1.0404
# EPOCH: 2    LOSS: 0.7046863779648488    MOMENTUM: 1.061208
# EPOCH: 3    LOSS: 0.6844704729313861    MOMENTUM: 1.08243216
# EPOCH: 4    LOSS: 0.6680520766576817    MOMENTUM: 1.1040808032
# EPOCH: 5    LOSS: 0.6545056883919397    MOMENTUM: 1.126162419264
# EPOCH: 6    LOSS: 0.6430955104529622    MOMENTUM: 1.14868566764928
# EPOCH: 7    LOSS: 0.6332904106438678    MOMENTUM: 1.1716593810022657
# EPOCH: 8    LOSS: 0.6247133541945032    MOMENTUM: 1.195092568622311
# EPOCH: 9    LOSS: 0.6170929983689685    MOMENTUM: 1.2189944199947573
# EPOCH: 10    LOSS: 0.6102290730461126    MOMENTUM: 1.2433743083946525
# EPOCH: 11    LOSS: 0.6039681996027562    MOMENTUM: 1.2682417945625455
# EPOCH: 12    LOSS: 0.5981837773887861    MOMENTUM: 1.2936066304537963
# EPOCH: 13    LOSS: 0.5927445838660791    MOMENTUM: 1.3194787630628724
# ...

# %%
shroom.plot_mushrooms(X, y)
X, y = shroom.generate_mushrooms(lambda i, j: (i-0.5)**2 + (j-0.5)**2 < 0.25, size_shrooms=10000)
y_pred = neural_net.eval(X)
shroom.plot_mushrooms(X, y_pred)
graphics.plot_losses(epochs, losses)

# %%
shroom.plot_mushroom_comparison(X, y, X, y_pred)
