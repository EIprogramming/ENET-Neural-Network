# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
import sys
sys.path.append('../')
from neural_net import NeuralNet
import examples.mushrooms as shroom
import graphics

# %%
df: pd.DataFrame = load_breast_cancer(as_frame=True).frame # type: ignore

df[df["target"] != 0]
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 19        13.540         14.36           87.46      566.3          0.09779
# 20        13.080         15.71           85.63      520.0          0.10750
# 21         9.504         12.44           60.34      273.9          0.10240
# 37        13.030         18.42           82.61      523.8          0.08983
# 46         8.196         16.84           51.71      201.9          0.08600
# ..           ...           ...             ...        ...              ...
# 558       14.590         22.68           96.39      657.1          0.08473
# 559       11.510         23.93           74.52      403.5          0.09261
# 560       14.050         27.15           91.38      600.4          0.09929
# 561       11.200         29.37           70.67      386.0          0.07449
# 568        7.760         24.54           47.92      181.0          0.05263
#
# ...

# %%
X_data, y_data = load_breast_cancer(return_X_y=True)
X: np.ndarray = np.array(X_data, dtype=float)
y: np.ndarray = np.array(y_data, dtype=float)
print(f"Shape of data:\n    X: {X.shape},\n    y: {y.shape}")
# Out:
# Shape of data:
#     X: (569, 30),
#     y: (569,)

# %%
from sklearn.model_selection import train_test_split

from layers.dense import Dense
from layers.input import Input


neural_net = NeuralNet(
    [(Input, 30), (Dense, 512), (Dense, 256), (Dense, 1)], learning_rate=0.000001, random_state=42)

neural_net.set_loss("BCE")


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

epochs = 150
losses, y_pred = neural_net.train(X_train, y_train, epochs, 1, validate=(X_test, y_test), binary=True, lr_scheduling=True, dropout=True)
# Out:
# EPOCH: 1    LOSS: 0.516717    LOSS CHANGE: 0    TEST ACCURACY: 0.3684    TEST ACCURACY CHANGE 0.3684    TIME: 0.062 s
# EPOCH: 2    LOSS: 0.498256    LOSS CHANGE: -0.01846    TEST ACCURACY: 0.3684    TEST ACCURACY CHANGE 0    TIME: 0.062 s
# EPOCH: 3    LOSS: 0.488719    LOSS CHANGE: -0.009537    TEST ACCURACY: 0.4035    TEST ACCURACY CHANGE 0.03509    TIME: 0.062 s
# EPOCH: 4    LOSS: 0.468929    LOSS CHANGE: -0.01979    TEST ACCURACY: 0.2982    TEST ACCURACY CHANGE -0.1053    TIME: 0.062 s
# EPOCH: 5    LOSS: 0.460258    LOSS CHANGE: -0.008671    TEST ACCURACY: 0.2982    TEST ACCURACY CHANGE 0    TIME: 0.064 s
# EPOCH: 6    LOSS: 0.442078    LOSS CHANGE: -0.01818    TEST ACCURACY: 0.3684    TEST ACCURACY CHANGE 0.07018    TIME: 0.062 s
# EPOCH: 7    LOSS: 0.43899    LOSS CHANGE: -0.003088    TEST ACCURACY: 0.4912    TEST ACCURACY CHANGE 0.1228    TIME: 0.062 s
# ...

# %%
graphics.plot_report(neural_net)

# %%
from sklearn.metrics import accuracy_score

y_pred = neural_net.predict(X[-100:])
y_pred_abs = np.where(y_pred >= 0.5, 1, 0)
accuracy = accuracy_score(y_pred_abs, y[-100:])
print(f"Test Data Accuracy: {100*accuracy}%")
# Out:
# Test Data Accuracy: 92.0%

# %%
print(neural_net.BCE(y_pred.flatten(), y[-100:])) # type:ignore
# Out:
# 0.2596411663611082

# %%
y_pred = neural_net.predict(X) # type: ignore
y_pred_abs = np.where(y_pred >= 0.5, 1, 0)
df["target predicted"] = y_pred_abs.flatten()
df[df["target"] != df["target predicted"]]
df[df["target"] == df["target predicted"]]
print(f"Percent accuracy on total data: {100*np.sum(df["target"] == df["target predicted"])/len(df["target"]):.4g}%")
# Out:
# Percent accuracy on total data: 89.28%

# %%
from sklearn.manifold import TSNE

def t_sne(df, df_target):
    X = df.drop(columns=["target", "target predicted"])
    tsne = TSNE(n_components=2, perplexity=30, random_state=42)
    X_embedded = tsne.fit_transform(X)
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(X_embedded[:, 0],
                X_embedded[:, 1],
                c=df_target)
    handles, labels = scatter.legend_elements()
    plt.title('t-SNE Plot')
    plt.xlabel('t-SNE1')
    plt.ylabel('t-SNE2')
    plt.show()

t_sne(df, df["target"])
t_sne(df, df["target predicted"])

# %%
t_sne(df[-100:], df["target"][-100:])
t_sne(df[-100:], df["target predicted"][-100:])

# %%
true_positives = df[(df["target"] == 1) & (df["target"] == df["target predicted"])]
false_positives = df[(df["target"] == 1) & (df["target"] != df["target predicted"])]

true_negatives = df[(df["target"] == 0) & (df["target"] == df["target predicted"])]
false_negatives = df[(df["target"] == 0) & (df["target"] != df["target predicted"])]


false_discovery_rate = len(false_positives)/(len(false_positives) + len(true_positives))
false_positive_rate = len(false_positives)/(len(false_positives) + len(true_negatives))
print(f"False Discovery Rate: {100 * false_discovery_rate:.4g}%")
print(f"False Positive Rate: {100 * false_positive_rate:.4g}%")
# Out:
# False Discovery Rate: 1.681%
# False Positive Rate: 3.681%
